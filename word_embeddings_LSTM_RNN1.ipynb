# %%
##libraries used tensorflow>2.0 and keras

# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# finding the tensorflow version

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#tensorflow>2.0

from tensorflow.keras.preprocessing.text import one_hot

# %%
#sentenses

sent = ["the world is a better place",
        "marvel series is my favorite movie",
        "I like DC movies",
        "the cat is eating the food",
        "tom and jerry is my favourite"
        
        ]

# %%
sent
# Out:
# ['the world is a better place',
#  'marvel series is my favorite movie',
#  'I like DC movies',
#  'the cat is eating the food',
#  'tom and jerry is my favourite']

# %%
#vocabulary size

voc_size =10000

# %%
#One Hot representation

one_hot_rep = [one_hot(words, voc_size) for words in sent]
print(one_hot_rep)
# Out:
# [[6683, 3143, 1484, 1878, 676, 2936], [5194, 1476, 1484, 2000, 4146, 3411], [649, 3123, 5700, 4186], [6683, 5440, 1484, 3081, 6683, 2625], [7030, 2249, 9043, 1484, 2000, 6398]]

# %%
#Word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length = 10
embedded_docs = pad_sequences(one_hot_rep, padding='post', maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[6683, 3143, 1484, 1878,  676, 2936,    0,    0,    0,    0],
#        [5194, 1476, 1484, 2000, 4146, 3411,    0,    0,    0,    0],
#        [ 649, 3123, 5700, 4186,    0,    0,    0,    0,    0,    0],
#        [6683, 5440, 1484, 3081, 6683, 2625,    0,    0,    0,    0],
#        [7030, 2249, 9043, 1484, 2000, 6398,    0,    0,    0,    0]],
#       dtype=int32)

# %%
#feature dimention =10

dim = 10

# %%
#building the model

model = Sequential()
model.add(Embedding(voc_size, 10,input_length=sent_length))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 10, 10)            100000
#
# =================================================================
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
## embeding word is === "the world is a better place"

embedded_docs[0]
# Out:
# array([6683, 3143, 1484, 1878,  676, 2936,    0,    0,    0,    0],
#       dtype=int32)

# %%
print(model.predict(embedded_docs))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# [[[ 0.01666461 -0.0175892  -0.01124416 -0.00657252  0.03283913
#     0.02063073 -0.03737141 -0.00818428  0.03003848  0.01987053]
#   [ 0.02144326  0.02457796  0.03722069  0.04919792 -0.04631629
#     0.04416628  0.04544112  0.0432541  -0.03476982  0.00184035]
#   [ 0.00587701  0.04382603  0.01466625  0.04812809  0.0403877
#     0.02524669 -0.03501447 -0.02929763 -0.00707927 -0.03937567]
#   [ 0.02922178  0.01467835 -0.03892195 -0.039768    0.01255748
#     0.03904158  0.01516554 -0.02106569 -0.04128141  0.04327257]
#   [ 0.03872873  0.03032039  0.02405271 -0.01934574  0.0136158
#    -0.02262571 -0.04356844 -0.01513062 -0.04684797 -0.03191241]
#   [-0.00597591  0.02033686  0.01038944  0.03256183  0.03916753
#    -0.00851316 -0.03833158 -0.01073547  0.02814564 -0.04768304]
#   [ 0.04739333 -0.02809472  0.0079545  -0.02240952 -0.0387712
#    -0.0226559  -0.00564158  0.0380108   0.00200149  0.03617543]
#   [ 0.04739333 -0.02809472  0.0079545  -0.02240952 -0.0387712
#    -0.0226559  -0.00564158  0.0380108   0.00200149  0.03617543]
#   [ 0.04739333 -0.02809472  0.0079545  -0.02240952 -0.0387712
#    -0.0226559  -0.00564158  0.0380108   0.00200149  0.03617543]
#   [ 0.04739333 -0.02809472  0.0079545  -0.02240952 -0.0387712
#    -0.0226559  -0.00564158  0.0380108   0.00200149  0.03617543